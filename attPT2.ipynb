# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Carregar o dataset
df = pd.read_csv('aluguel_duas_variaveis_com_ruido.csv')

# Exploração dos dados
print("Primeiras linhas:\n")
print(df.head())
print("\nEstatísticas:")
print(df.describe())

# Visualização da relação entre as variáveis
plt.figure(figsize=(12, 6))

# Gráfico de dispersão para a relação entre Área e Preço do Aluguel
plt.subplot(1, 2, 1)
plt.scatter(df['Area'], df['Preco'])
plt.xlabel('Área (m²)')
plt.ylabel('Preço do Aluguel (R$)')
plt.title('Preço do Aluguel x Área da Casa')

# Gráfico de dispersão para a relação entre Quartos e Preço do Aluguel
plt.subplot(1, 2, 2)
plt.scatter(df['Quartos'], df['Preco'])
plt.xlabel('Número de Quartos')
plt.ylabel('Preço do Aluguel (R$)')
plt.title('Preço do Aluguel x Número de Quartos')

plt.tight_layout()
plt.show()

# Preparação dos dados
X = df[['Area', 'Quartos']]
y = df['Preco']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Construção do modelo
model = LinearRegression()
model.fit(X_train, y_train)

# Avaliação do modelo
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"R²: {r2:.2f}")
# Out:
# Primeiras linhas:
#
#    Area  Quartos        Preco
# 0   132        2  3786.649334
# 1   136        5  4694.382578
# 2   101        3  3472.955795
# 3   218        1  5452.604056
# 4    50        3  2590.143495
#
# Estatísticas:
#               Area      Quartos        Preco
# count  1000.000000  1000.000000  1000.000000
# mean    165.139000     3.000000  4862.066832
# std      77.313369     1.421978  1613.148365
# min      30.000000     1.000000  1309.140452
# 25%      98.000000     2.000000  3574.948755
# 50%     166.000000     3.000000  4901.455061
# 75%     231.000000     4.000000  6177.701103
# max     299.000000     5.000000  8369.327053
# R²: 0.98
